# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pycountry_convert

# %%
pd.options.display.max_seq_items = 10

# %% [markdown]
#  Read the file.

# %%
df = pd.read_parquet('Result_file_compressed.parquet')
df.head()
# Out:
#                Date: Time:                Location:      Operator: Flight #:  \
# 0   January 15, 2023  1050           Pokhara, Nepal  Yeti Airlines     YT691
# 1  November 21, 2022  1015       Medellín, Colombia   AeroPaca SAS         ?
# 2  November 18, 2022  1511               Lima, Peru          LATAM    LA2213
# 3  November 06, 2022  0853         Bukoba, Tanzania  Precision Air     PW494
# 4      July 16, 2022  2247  Eleftheroupolis, Greece       Meridian   MEM3032
#
#                   Route:                         AC  Type: Registration:  \
# 0    Kathmandu - Pokhara               ATR 72-500-72-212-A         9NANC
# 1     Medellín - Pizarro  Piper PA-31-350 Navajo Chieftain       HK-5121
# 2         Lima - Juliaca                   Airbus 320-271N        CC-BHB
# 3  Dar es-Salaam -Bukoba                        ATR 42-500        5H-PWF
# 4             Nis- Amman                     Antonov An-12        UR-CIC
#
#      cn / ln:                      Aboard:                Fatalities: Ground:  \
# 0         754    72 (passengers:68 crew:4)  72 (passengers:68 crew:4)       0
# 1  31-7652004      8 (passengers:6 crew:2)    8 (passengers:6 crew:2)       0
# 2        7864  108 (passengers:102 crew:6)    0 (passengers:0 crew:0)       2
# 3         819   43 (passengers:39 crew:39)  19 (passengers:17 crew:2)       0
# 4    01347701      8 (passengers:0 crew:8)    8 (passengers:0 crew:8)       0
#
#                                             Summary:
# 0  Before approach, the pilot requested a change ...
# 1  The plane was chartered to carry a team of six...
# 2  The Airbus A320 collided with a fire truck whi...
# 3  While on final approach to Bukoba Airport, the...
# 4  The cargo plane carrying eight crew members an...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4596 entries, 0 to 4595
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date:          4596 non-null   object
#  1   Time:          4596 non-null   object
#  2   Location:      4596 non-null   object
#  3   Operator:      4596 non-null   object
#  4   Flight #:      4596 non-null   object
#  5   Route:         4596 non-null   object
#  6   AC  Type:      4596 non-null   object
#  7   Registration:  4596 non-null   object
#  8   cn / ln:       4596 non-null   object
#  9   Aboard:        4596 non-null   object
#  10  Fatalities:    4596 non-null   object
#  11  Ground:        4596 non-null   object
#  12  Summary:       4596 non-null   object
# dtypes: object(13)
# memory usage: 466.9+ KB

# %% [markdown]
# Drop the summary column.

# %%
df = df.drop('Summary:', axis=1)

# %% [markdown]
# Remove the colons from each of the column names and remove the spaces

# %%
df.columns = df.columns.str[:-1]
replacement_dict = {'  ': '_', ' ': '_',  '/': '', '#': 'No', '__': '_'}

for original, replacement in replacement_dict.items():
    df.columns = df.columns.str.replace(original, replacement)
    
df.columns
# Out:
# Index(['Date', 'Time', 'Location', 'Operator', 'Flight_No',
#        ...
#        'Registration', 'cn_ln', 'Aboard', 'Fatalities', 'Ground'],
#       dtype='object', length=12)

# %% [markdown]
# Performing some data type conversions

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# In the time format, let's remove the colons and other anomalies so that we can parse them later on.

# %%
symbols_to_replace = [':', ';', 'c: ', 'c:', 'Z', 'c ', 'c']
replacement_mapping = {symbol: '' for symbol in symbols_to_replace}

for symbol, replacement in replacement_mapping.items():
    df['Time'] = df['Time'].str.replace(symbol, replacement)

# %% [markdown]
# Introduce a new 'decade' column.

# %%
df['Decade'] = df['Date'].dt.year // 10 * 10

# %% [markdown]
# Extracting the country name from the location column

# %% [markdown]
# Replace some exceptions.

# %%
df['Location'] = df['Location'].replace({
    'Minsk, Belarus, USSR': 'Minsk, Belarus',
    'Southern Belarus, USSR': 'Southern Belarus, Belarus'
})

# %%
location_parts = df['Location'].str.split(',')

df['City'] = location_parts.apply(lambda x: ', '.join(x[:-1]))
df['Country/State/Other'] = location_parts.apply(lambda x: x[-1].strip())

# %%
values = df['Country/State/Other'].unique()
values.sort()
values
# Out:
# array(['110 miles West of Ireland', '175 miles off the Egyptian coast',
#        '325 miles east of Wake Island', '800 miles east of Newfoundland',
#        '?', 'AK', 'Aegean Sea', 'Afghanistan', 'Afghanstan', 'Africa',
#        'Airzona', 'Alabama', 'Alaksa', 'Alaska', 'Albania', 'Algeria',
#        'Algiers', 'American Samoa', 'Amsterdam', 'Andes', 'Angola',
#        'Antarctica', 'Antigua', 'Aregntina', 'Argentina', 'Arizona',
#        'Arkansas', 'Armenia', 'Atlantic Ocean',
#        'Atlantic Ocean between N.Y. and Bermuda',
#        'Atlantic Ocean off Florida', 'Australia', 'Australila', 'Austria',
#        'Azerbaijan', 'Azores', 'Azores (Portugal)', 'BO', 'Baangladesh',
#        'Bahamas', 'Bahrain', 'Baltic Sea', 'Bangladesh', 'Barbados',
#        'Barquisimeto Venezuela', 'Belarus', 'Belgian Congo',
#        'Belgian Congo (Zaire)', 'Belgium', 'Belgium Congo', 'Benin',
#        'Bermuda', 'Bhutan', 'Black Sea', 'Boliva', 'Bolivia', 'Borneo',
#        'Bosnia', 'Bosnia-Herzegovina', 'Botswana', 'Brazil',
#        'British Cameroons', 'British Columbia Canada',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Bulgeria',
#        'Burma', 'Burma (Myanmar)', 'CA', 'Cailifornia', 'California',
#        'Californiia', 'Calilfornia', 'Cambodia', 'Cameroon', 'Cameroons',
#        'Canada', 'Canada2', 'Canary Islands', 'Cape Verde',
#        'Cape Verde Islands', 'Central African Republic',
#        'Central Mozambique', 'Chad', 'Chechnya', 'Chile', 'China',
#        'Coatia', 'Coloado', 'Colombia', 'Colorado', 'Columbia',
#        'Comoro Islands', 'Comoros', 'Comoros Islands', 'Congo',
#        'Congo Democratic Republic', 'Connecticut', 'Cook Islands',
#        'Costa Rica', 'Crete', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Czechoslovakia', 'D.C.', 'DR Congo', 'Delaware',
#        'Deleware', 'Democratic Republic Cogo',
#        'Democratic Republic Congo', 'Democratic Republic of Congo',
#        'Democratic Republic of the Congo', 'Democtratic Republic Congo',
#        'Denmark', 'Desertores Island Región de Los Lagos', 'Djbouti',
#        'Djibouti', 'Domincan Republic', 'Dominican Republic',
#        'Dutch Guyana', 'East Germany', 'East Pakistan',
#        'East Pakistan (Bangladesh)', 'East Sardinia', 'East Timor',
#        'Eastern Libya', 'Ecuador', 'Egypt', 'El Salvador',
#        'En route from Argentina to California', 'England',
#        'English Channel', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Eugene Island', 'Fiji', 'Finland', 'Florida',
#        'Forest-in-Teesdale. United Kingdom', 'Fox Glacier Airstrip',
#        'France', 'French Cameroons', 'French Equatorial Africa',
#        'French Indo-China', 'French Polynesia', 'French Somaliland',
#        'French West Africa', 'French West Indies', 'Gabon', 'Gambia',
#        'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Great Inagua',
#        'Greece', 'Greenland', 'Guadeloupe', 'Guam', 'Guatemala', 'Guinea',
#        'Guizhou Province', 'Gulf of Finland', 'Gulf of Karkinitsky',
#        'Gulf of Mexico', 'Gulf of Oman', 'Gulf of Sirte',
#        'Gulf of Thailand', 'Gulf of Tonkin', 'Guyana', 'HI', 'HI)',
#        'Haiti', 'Hati', 'Hawaii', 'Honduras', 'Hong Kong', 'Hunary',
#        'Hungary', 'Iceland', 'Idaho', 'Ilha Grande Rio de Janeiro',
#        'Ilinois', 'Illinois', 'India', 'India.', 'Indian', 'Indian Ocean',
#        'Indiana', 'Indonesia', 'Inodnesia', 'Iowa', 'Iran', 'Iraq',
#        'Ireland', 'Islay Island', 'Isle of Man', 'Italy', 'Ivory Coast',
#        'Jamacia', 'Jamaica', 'Japan', 'Java Sea', 'Jersey', 'Jordan',
#        'Kansas', 'Katanga', 'Kazakhstan', 'Kent', 'Kentucky', 'Kenya',
#        'Khmer Republic', 'Kirghizia', 'Kosovo', 'Kuwait', 'Kyrgyzstan',
#        'Labrador', 'Laos', 'Latvia', 'Lebanon', 'Leeward Islands',
#        'Lesotho', 'Liberia', 'Libya', 'Louisiana', 'Luxembourg',
#        'Macedonia', 'Madagascar', 'Maine', 'Malawi', 'Malaya', 'Malaysia',
#        'Mali', 'Malta', 'Malta International Airport', 'Manitoba',
#        'Manmar', 'Mariana Islands', 'Marshall Islands', 'Martinique',
#        'Maryland', 'Massachusetts', 'Massachutes', 'Mauretania',
#        'Mauritania', 'Mediterranean Sea', 'Mexic', 'Mexico', 'Michigan',
#        'Micronesia', 'Midway Island Naval Air Station', 'Milford Sound',
#        'Minnesota', 'Minnisota', 'Mississipi', 'Mississippi', 'Missouri',
#        'Moldova', 'Mongolia', 'Montana', 'Montserrat', 'Morocco',
#        'Morroco', 'Mozambique', 'Mt. Helmos. Greece', 'Myanmar',
#        'NE of Bermuda', 'NY', 'Nambia', 'Namibia', 'Napal',
#        'Near Hong Kong', 'Near Hong Kong International Airport',
#        'Near Houma Louisiana', 'Near Irkutsk Russia',
#        'Near Jacquinot Bay New Guinea', 'Near Karkov', 'Near Lete Pass',
#        'Near Nag', 'Near Petreasa Romania', 'Near Tachikawa Air Base',
#        'Near Villia Greece', 'Nebraska', 'Nepal', 'Netherlands',
#        'Netherlands Antilles', 'Netherlands Indies', 'Nevada',
#        'New Caledonia', 'New Guinea', 'New Hampshire', 'New Jersey',
#        'New Mexico', 'New York', 'New York (Idlewild)', 'New Zealand',
#        'Newfoundland', 'Nicaragua', 'Niger', 'Nigeria', 'North Atlantic',
#        'North Atlantic Ocean', 'North Carolina', 'North Korea',
#        'North Pacific Ocean', 'North Sea', 'Northeast Laos',
#        'Northern Afghanistan', 'Northern Iraq', 'Northern Ireland',
#        'Northern Israel', 'Northwest Territories Canada', 'Norway',
#        'Off Algiers', 'Off Bahrain', 'Off Bimini', 'Off Chili',
#        'Off Gibraltar', 'Off Hong Kong', 'Off Irish coast',
#        'Off Malta-Luqa', 'Off Northern Germany', 'Off Puerto Rico',
#        'Off Spain', 'Off São Tomé Island',
#        'Off Tabones Island Philippines', 'Off Taiwan',
#        'Off Turks and Caicos Islands', 'Off Wake Island',
#        'Off West Africa', 'Off Western Africa', 'Off the Alaska coast',
#        'Off the Oregon coast', 'Off the Panama coast',
#        'Off the coast of France', 'Off western Denmark', 'Ohio',
#        'Okinawa', 'Oklahoma', 'Oman', 'Ontario', 'Oregon',
#        'Over North Carolina', 'Over the Andaman Sea',
#        'Over the Atlantic Ocean', 'Over the Carribean Sea',
#        'Over the English Channel', 'Over the Gulf of Finland',
#        'Over the Mediterranean', 'Over the Mediterranean Sea',
#        'Over the North Atlantic', 'Over the North Pacific Ocean',
#        'Over the North Sea', 'Over the Pacific Ocean', 'Pacific Ocean',
#        'Pacific Ocean between Hong Kong and Macao',
#        'Pacific Ocean between Manila and Guam', 'Pakistan', 'Panama',
#        'Papua', 'Papua New Guinea', 'Paraguay', 'Pennsylvania',
#        'Persian Gulf', 'Peru', 'Pest Hungary', 'Philipines',
#        'Philippine Sea', 'Philippines', 'Phillipines', 'Poland',
#        'Portugal', 'Puerto Rico', 'Qatar', 'Qld. Australia',
#        'Quebec Canada', 'Queensland Australia', 'Republic of Djibouti',
#        'Republic of Georgia', 'Reunion', 'Rhode Island',
#        'Rhodesia (Zimbabwe)', 'Romania', 'Russia', 'Russian', 'Rwanda',
#        'Saint Lucia Island', 'Samoa', 'Santiago de Cuba',
#        'Sao Gabriel de Cachoeria', 'Sarawak', 'Saskatchewan',
#        'Saudi Arabia', 'Saudia Arabia', 'Scotland', 'Sea of Japan',
#        'Senegal', 'Sierra Leone', 'Sierre Leone', 'Singapore', 'Slovakia',
#        'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa',
#        'South Atlantic Ocean', 'South Australia', 'South Carolina',
#        'South Dakota', 'South Dekota', 'South Indian Ocean',
#        'South Kazakistan', 'South Korea', 'South Korean', 'South Sudan',
#        'South Vietnam', 'South Yemen', 'South of Gibraltar',
#        'South-West Africa (Namibia)', 'Southeastern Bolivia',
#        'Soviet Union', 'Spain', 'Spain Canary Islands', 'Sri Lanka',
#        'Sudan', 'Surinam', 'Suriname', 'Swden', 'Sweden', 'Switzerland',
#        'Syria', 'Tahiti', 'Taiwan', 'Taiwan (Formosa)', 'Tajikistan',
#        'Tanganyika', 'Tanzania', 'Tasmania', 'Tennesee', 'Tennessee',
#        'Territory of New Guinea', 'Texas', 'Thailand', 'The Netherlands',
#        'Timor', 'Trinidad', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'U.S. Samoa', 'U.S. Virgin Islands', 'UAE', 'UAR', 'UK',
#        'US Virgin Islands', 'USSR', 'Uganda', 'Ukraine', 'Unied Kingdom',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Upper Volta', 'Uruguay', 'Utah', 'Uzbekistan', 'Uzbekstan',
#        'Vanuatu', 'Venezuela', 'Vermont', 'Vietnam', 'Virgin Islands',
#        'Virginia', 'WY', 'Wales', 'Washingon', 'Washington',
#        'Washington D.C.', 'West Germany', 'West Indies', 'West Pakistan',
#        'West Virginia', 'Western Samoa', 'Wisconsin', 'Wisconson',
#        'Wyoming', 'Yemen', 'Yugosalvia', 'Yugoslavia', 'Yukon Territory',
#        'Zaire', 'Zambia', 'Zimbabwe', 'Zimbabwe)', 'bulgaria',
#        'off Angola', 'off Australia',
#        'off the Philippine island of Elalat'], dtype=object)

# %% [markdown]
# So now a problem is that US states are used, and the name of the country is not.

# %%
df_states = pd.read_html('https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States')

# %%
df_states = df_states[1]

# %%
state_names = df_states.iloc[:, 0].values

# %%
state_names
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky[B]', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts[B]', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania[B]',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia[B]', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# There are some names which contain [B]. These are now replaced.

# %%
state_names = [name.replace('[B]', '') for name in state_names]

# %% [markdown]
# There are some spelling mistakes, which are now corrected.

# %%
area_values = df['Country/State/Other'].unique()
area_values.sort()
for value in area_values:
    print(value)
# Out:
# 110 miles West of Ireland
# 175 miles off the Egyptian coast
# 325 miles east of Wake Island
# 800 miles east of Newfoundland
# ?
# AK
# Aegean Sea
# Afghanistan
# Afghanstan
# Africa
# Airzona
# Alabama
# Alaksa
# Alaska
# Albania
# Algeria
# Algiers
# American Samoa
# Amsterdam
# Andes
# Angola
# Antarctica
# Antigua
# Aregntina
# Argentina
# Arizona
# Arkansas
# Armenia
# Atlantic Ocean
# Atlantic Ocean between N.Y. and Bermuda
# Atlantic Ocean off Florida
# Australia
# Australila
# Austria
# Azerbaijan
# Azores
# Azores (Portugal)
# BO
# Baangladesh
# Bahamas
# Bahrain
# Baltic Sea
# Bangladesh
# Barbados
# Barquisimeto Venezuela
# Belarus
# Belgian Congo
# Belgian Congo (Zaire)
# Belgium
# Belgium Congo
# Benin
# Bermuda
# Bhutan
# Black Sea
# Boliva
# Bolivia
# Borneo
# Bosnia
# Bosnia-Herzegovina
# Botswana
# Brazil
# British Cameroons
# British Columbia Canada
# British Virgin Islands
# Brunei
# Bulgaria
# Bulgeria
# Burma
# Burma (Myanmar)
# CA
# Cailifornia
# California
# Californiia
# Calilfornia
# Cambodia
# Cameroon
# Cameroons
# Canada
# Canada2
# Canary Islands
# Cape Verde
# Cape Verde Islands
# Central African Republic
# Central Mozambique
# Chad
# Chechnya
# Chile
# China
# Coatia
# Coloado
# Colombia
# Colorado
# Columbia
# Comoro Islands
# Comoros
# Comoros Islands
# Congo
# Congo Democratic Republic
# Connecticut
# Cook Islands
# Costa Rica
# Crete
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Czechoslovakia
# D.C.
# DR Congo
# Delaware
# Deleware
# Democratic Republic Cogo
# Democratic Republic Congo
# Democratic Republic of Congo
# Democratic Republic of the Congo
# Democtratic Republic Congo
# Denmark
# Desertores Island Región de Los Lagos
# Djbouti
# Djibouti
# Domincan Republic
# Dominican Republic
# Dutch Guyana
# East Germany
# East Pakistan
# East Pakistan (Bangladesh)
# East Sardinia
# East Timor
# Eastern Libya
# Ecuador
# Egypt
# El Salvador
# En route from Argentina to California
# England
# English Channel
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Eugene Island
# Fiji
# Finland
# Florida
# Forest-in-Teesdale. United Kingdom
# Fox Glacier Airstrip
# France
# French Cameroons
# French Equatorial Africa
# French Indo-China
# French Polynesia
# French Somaliland
# French West Africa
# French West Indies
# Gabon
# Gambia
# Georgia
# Germany
# Ghana
# Gibraltar
# Great Inagua
# Greece
# Greenland
# Guadeloupe
# Guam
# Guatemala
# Guinea
# Guizhou Province
# Gulf of Finland
# Gulf of Karkinitsky
# Gulf of Mexico
# Gulf of Oman
# Gulf of Sirte
# Gulf of Thailand
# Gulf of Tonkin
# Guyana
# HI
# HI)
# Haiti
# Hati
# Hawaii
# Honduras
# Hong Kong
# Hunary
# Hungary
# Iceland
# Idaho
# Ilha Grande Rio de Janeiro
# Ilinois
# Illinois
# India
# India.
# Indian
# Indian Ocean
# Indiana
# Indonesia
# Inodnesia
# Iowa
# Iran
# Iraq
# Ireland
# Islay Island
# Isle of Man
# Italy
# Ivory Coast
# Jamacia
# Jamaica
# Japan
# Java Sea
# Jersey
# Jordan
# Kansas
# Katanga
# Kazakhstan
# Kent
# Kentucky
# Kenya
# Khmer Republic
# Kirghizia
# Kosovo
# Kuwait
# Kyrgyzstan
# Labrador
# Laos
# Latvia
# Lebanon
# Leeward Islands
# Lesotho
# Liberia
# Libya
# Louisiana
# Luxembourg
# Macedonia
# Madagascar
# Maine
# Malawi
# Malaya
# Malaysia
# Mali
# Malta
# Malta International Airport
# Manitoba
# Manmar
# Mariana Islands
# Marshall Islands
# Martinique
# Maryland
# Massachusetts
# Massachutes
# Mauretania
# Mauritania
# Mediterranean Sea
# Mexic
# Mexico
# Michigan
# Micronesia
# Midway Island Naval Air Station
# Milford Sound
# Minnesota
# Minnisota
# Mississipi
# Mississippi
# Missouri
# Moldova
# Mongolia
# Montana
# Montserrat
# Morocco
# Morroco
# Mozambique
# Mt. Helmos. Greece
# Myanmar
# NE of Bermuda
# NY
# Nambia
# Namibia
# Napal
# Near Hong Kong
# Near Hong Kong International Airport
# Near Houma Louisiana
# Near Irkutsk Russia
# Near Jacquinot Bay New Guinea
# Near Karkov
# Near Lete Pass
# Near Nag
# Near Petreasa Romania
# Near Tachikawa Air Base
# Near Villia Greece
# Nebraska
# Nepal
# Netherlands
# Netherlands Antilles
# Netherlands Indies
# Nevada
# New Caledonia
# New Guinea
# New Hampshire
# New Jersey
# New Mexico
# New York
# New York (Idlewild)
# New Zealand
# Newfoundland
# Nicaragua
# Niger
# Nigeria
# North Atlantic
# North Atlantic Ocean
# North Carolina
# North Korea
# North Pacific Ocean
# North Sea
# Northeast Laos
# Northern Afghanistan
# Northern Iraq
# Northern Ireland
# Northern Israel
# Northwest Territories Canada
# Norway
# Off Algiers
# Off Bahrain
# Off Bimini
# Off Chili
# Off Gibraltar
# Off Hong Kong
# Off Irish coast
# Off Malta-Luqa
# Off Northern Germany
# Off Puerto Rico
# Off Spain
# Off São Tomé Island
# Off Tabones Island Philippines
# Off Taiwan
# Off Turks and Caicos Islands
# Off Wake Island
# Off West Africa
# Off Western Africa
# Off the Alaska coast
# Off the Oregon coast
# Off the Panama coast
# Off the coast of France
# Off western Denmark
# Ohio
# Okinawa
# Oklahoma
# Oman
# Ontario
# Oregon
# Over North Carolina
# Over the Andaman Sea
# Over the Atlantic Ocean
# Over the Carribean Sea
# Over the English Channel
# Over the Gulf of Finland
# Over the Mediterranean
# Over the Mediterranean Sea
# Over the North Atlantic
# Over the North Pacific Ocean
# Over the North Sea
# Over the Pacific Ocean
# Pacific Ocean
# Pacific Ocean between Hong Kong and Macao
# Pacific Ocean between Manila and Guam
# Pakistan
# Panama
# Papua
# Papua New Guinea
# Paraguay
# Pennsylvania
# Persian Gulf
# Peru
# Pest Hungary
# Philipines
# Philippine Sea
# Philippines
# Phillipines
# Poland
# Portugal
# Puerto Rico
# Qatar
# Qld. Australia
# Quebec Canada
# Queensland Australia
# Republic of Djibouti
# Republic of Georgia
# Reunion
# Rhode Island
# Rhodesia (Zimbabwe)
# Romania
# Russia
# Russian
# Rwanda
# Saint Lucia Island
# Samoa
# Santiago de Cuba
# Sao Gabriel de Cachoeria
# Sarawak
# Saskatchewan
# Saudi Arabia
# Saudia Arabia
# Scotland
# Sea of Japan
# Senegal
# Sierra Leone
# Sierre Leone
# Singapore
# Slovakia
# Slovenia
# Solomon Islands
# Somalia
# South Africa
# South Atlantic Ocean
# South Australia
# South Carolina
# South Dakota
# South Dekota
# South Indian Ocean
# South Kazakistan
# South Korea
# South Korean
# South Sudan
# South Vietnam
# South Yemen
# South of Gibraltar
# South-West Africa (Namibia)
# Southeastern Bolivia
# Soviet Union
# Spain
# Spain Canary Islands
# Sri Lanka
# Sudan
# Surinam
# Suriname
# Swden
# Sweden
# Switzerland
# Syria
# Tahiti
# Taiwan
# Taiwan (Formosa)
# Tajikistan
# Tanganyika
# Tanzania
# Tasmania
# Tennesee
# Tennessee
# Territory of New Guinea
# Texas
# Thailand
# The Netherlands
# Timor
# Trinidad
# Tunisia
# Turkey
# Turkmenistan
# U.S. Samoa
# U.S. Virgin Islands
# UAE
# UAR
# UK
# US Virgin Islands
# USSR
# Uganda
# Ukraine
# Unied Kingdom
# United Arab Emirates
# United Kingdom
# United States
# Upper Volta
# Uruguay
# Utah
# Uzbekistan
# Uzbekstan
# Vanuatu
# Venezuela
# Vermont
# Vietnam
# Virgin Islands
# Virginia
# WY
# Wales
# Washingon
# Washington
# Washington D.C.
# West Germany
# West Indies
# West Pakistan
# West Virginia
# Western Samoa
# Wisconsin
# Wisconson
# Wyoming
# Yemen
# Yugosalvia
# Yugoslavia
# Yukon Territory
# Zaire
# Zambia
# Zimbabwe
# Zimbabwe)
# bulgaria
# off Angola
# off Australia
# off the Philippine island of Elalat

# %%
df.query("`Country/State/Other` == 'BO'")
# Out:
#           Date  Time                Location                 Operator  \
# 662 2000-12-11  1445  Near Sumacal, Beni, BO  Servicio Aereo Manchupo
#
#     Flight_No                   Route     AC_Type Registration cn_ln  \
# 662         ?  Cashaschanes - Sumacal  Cessna 206      CP-1721     ?
#
#                       Aboard               Fatalities Ground  Decade  \
# 662  6 (passengers:5 crew:1)  6 (passengers:5 crew:1)      0    2000
#
#                     City Country/State/Other
# 662  Near Sumacal,  Beni                  BO

# %%
df['Country/State/Other'] = df['Country/State/Other'].replace({
    'AK': 'Alaska',
    'Afghanstan': 'Afghanistan',
    'Airzona': 'Arizona',
    'Alaksa': 'Alaska',
    'Aregntina': 'Argentina',
    'Australila': 'Australia',
    'Baangladesh': 'Bangladesh',
    'Azores (Portugal)': 'Azores',
    'Belgian Congo (Zaire)': 'Belgian Congo',
    'Belgium Congo': 'Belgian Congo',
    'BO': 'Bolivia',
    'Boliva': 'Bolivia',
    'Bulgeria': 'Bulgaria',
    'Burma': 'Myanmar',
    'Burma (Myanmar)': 'Myanmar',
    'CA': 'California',
    'Cailifornia': 'California',
    'Californiia': 'California',
    'Calilfornia': 'California',
    'Cameroons': 'Cameroon',
    'Canada2': 'Canada',
    'Coatia': 'Croatia',
    'Coloado': 'Colorado',
    'Colombia': 'Columbia',
    'Comoro Islands': 'Comoros Islands',
    'Comoros': 'Comoros Islands',
    'D.C.': 'Washington',
    'Deleware': 'Delaware',
    'Democratic Republic Cogo': 'Democratic Republic of the Congo',
    'Democratic Republic Congo': 'Democratic Republic of the Congo',
    'Democratic Republic of Congo': 'Democratic Republic of the Congo',
    'Democtratic Republic Congo': 'Democratic Republic of the Congo',
    'Djbouti': 'Djibouti',
    'Domincan Republic': 'Dominican Republic',
    'Forest-in-Teesdale. United Kingdom': 'United Kingdom',
    'HI': 'Hawaii',
    'HI)': 'Hawaii',
    'Ilinois': 'Illinois',
    'India.': 'India',
    'Indian': 'India',
    'Inodnesia': 'Indonesia',
    'Jamacia': 'Jamaica',
    'Kent': 'United Kingdom',
    'Malta International Airport': 'Malta',
    'Massachutes': 'Massachusetts',
    'Mauretania': 'Mauritania',
    'Mexic': 'Mexico',
    'Minnisota': 'Minnesota',
    'Mississipi': 'Mississippi',
    'Morroco': 'Morocco',
    'Napal': 'Nepal',
    'New York (Idlewild)': 'New York',
    'Papua': 'Papua New Guinea',
    'Philippines': 'Phillipines',
    'Republic of Djibouti': 'Djibouti',
    'Republic of Georgia': 'Georgia',
    'Qld. Australia': 'Australia',
    'Quebec Canada': 'Canada',
    'Queensland Australia': 'Australia',
    'Russian': 'Russia',
    'Saskatchewan': 'Canada',
    'Saudia Arabia': 'Saudi Arabia',
    'South Dekota': 'South Dakota',
    'Surinam': 'Suriname',
    'Swden': 'Sweden',
    'Taiwan (Formosa)': 'Taiwan',
    'Tennesee': 'Tennessee',
    'The Netherlands': 'Netherlands',
    'Unied Kingdom': 'United Kingdom',
    'WY': 'Wyoming',
    'Washingon': 'Washington',
    'Wisconson': 'Wisconsin',
    'Yugosalvia': 'Yugoslavia',
    'Zimbabwe)': 'Zimbabwe',
    'bulgaria': 'Bulgaria',
    'UK': 'United Kingdom',
    'England': 'United Kingdom',
    
    # DOing the rest
    '110 miles West of Ireland': 'Ireland',
    '175 miles off the Egyptian coast': 'Egypt',
    '325 miles east of Wake Island': 'Pacific Ocean',
    'Amsterdam': 'Netherlands',
    'Atlantic Ocean between N.Y. and Bermuda': 'Atlantic Ocean',
    'Atlantic Ocean off Florida': 'Atlantic Ocean',
    'Azores': 'Atlantic Ocean',
    'Barquisimeto Venezuela': 'Venezuela',
    'Chechnya': 'Russia',
    'Congo Democratic Republic': 'Democratic Republic of the Congo',
    'Crete': 'Greece',
    'DR Congo': 'Democratic Republic of Congo',
    'Dutch Guyana': 'Guyana',
    'East Germany': 'Germany',
    'East Pakistan': 'Pakistan',
    'East Pakistan (Bangladesh)': 'Bangladesh',
    'East Sardinia': 'Italy',
    'East Libya': 'Libya',
    'En route from Argentina to California': 'Argentina',
    'English Channel': 'United Kingdom',
    'Fox Glacier Airstrip': 'New Zealand',
    'Great Inagua': 'Bahamas',
    'Guizhou Province': 'China',
    'Gulf of Finland': 'Finland',
    'Gulf of Mexico': 'Mexico',
    'Gulf of Oman': 'Oman',
    'Gulf of Thailand': 'Thailand',
    'Hati': 'Haiti',
    'Hunary': 'Hungary',
    'Ilha Grande Rio de Janeiro': 'Brazil',
    'Islay Island': 'United Kingdom',
    'Kirghizia': 'Kyrgyzstan',
    'Manitoba': 'Canada',
    'Manmar': 'Myanmar',
    'Midway Island Naval Air Station': 'United States of America',
    'Milford Sound': 'New Zealand',
    'Mt. Helmos. Greece': 'Greece',
    'NE of Bermuda': 'Bermuda',
    'NY': 'New York',
    'Near Hong Kong': 'Hong Kong',
    'Near Hong Kong International Airport': 'Hong Kong',
    'Near Houma Louisiana': 'Louisiana',
    'Near Irkutsk Russia': 'Russia',
    'Near Jacquinot Bay New Guinea': 'Papua New Guinea',
    'Near Karkov': 'Ukraine',
    'Near Lete Pass': 'Nepal',
    'Near Petreasa Romania': 'Romania',
    'Near Tachikawa Air Base': 'Japan',
    'Near Villia Greece': 'Greece',
    'Newfoundland': 'Canada',
    'North Atlantic': 'Atlantic Ocean',
    'North Atlantic Ocean': 'Atlantic Ocean',
    'North Pacific Ocean': 'Pacific Ocean',
    'Northeast Laos': 'Laos',
    'Northern Afghanistan': 'Afghanistan',
    'Northern Iraq': 'Iraq',
    'Northern Ireland': 'Ireland',
    'Northern Israel': 'Israel',
    'Northwest Territories Canada': 'Canada',
    'Czechoslovakia': 'Czech Republic',
    'Bosnia-Herzegovina': 'Bosnia and Herzegovina',
    'Bosnia': 'Bosnia and Herzegovina',
    'Algiers': 'Algeria'
})

# %% [markdown]
# If the country/state/other column contains one of the US state names,show it as USA.
#
# Also preserve the state name in another column

# %%
temp = np.where(df['Country/State/Other'].isin(state_names), 'United States of America', df['Country/State/Other'])
df['Country_new'] = temp
df['US_State'] = np.where(df['Country/State/Other'].isin(state_names), df['Country/State/Other'], None)

# %% [markdown]
# Now replace the country

# %%
df = df.drop('Country/State/Other', axis=1)
df = df.rename(columns={'Country_new': 'Country'})
df = df.drop('Location', axis=1)

# %%
df.head()
# Out:
#         Date  Time       Operator Flight_No                  Route  \
# 0 2023-01-15  1050  Yeti Airlines     YT691    Kathmandu - Pokhara
# 1 2022-11-21  1015   AeroPaca SAS         ?     Medellín - Pizarro
# 2 2022-11-18  1511          LATAM    LA2213         Lima - Juliaca
# 3 2022-11-06  0853  Precision Air     PW494  Dar es-Salaam -Bukoba
# 4 2022-07-16  2247       Meridian   MEM3032             Nis- Amman
#
#                             AC_Type Registration       cn_ln  \
# 0               ATR 72-500-72-212-A        9NANC         754
# 1  Piper PA-31-350 Navajo Chieftain      HK-5121  31-7652004
# 2                   Airbus 320-271N       CC-BHB        7864
# 3                        ATR 42-500       5H-PWF         819
# 4                     Antonov An-12       UR-CIC    01347701
#
#                         Aboard                 Fatalities Ground  Decade  \
# 0    72 (passengers:68 crew:4)  72 (passengers:68 crew:4)      0    2020
# 1      8 (passengers:6 crew:2)    8 (passengers:6 crew:2)      0    2020
# 2  108 (passengers:102 crew:6)    0 (passengers:0 crew:0)      2    2020
# 3   43 (passengers:39 crew:39)  19 (passengers:17 crew:2)      0    2020
# 4      8 (passengers:0 crew:8)    8 (passengers:0 crew:8)      0    2020
#
#               City   Country US_State
# 0          Pokhara     Nepal     None
# 1         Medellín  Columbia     None
# 2             Lima      Peru     None
# 3           Bukoba  Tanzania     None
# 4  Eleftheroupolis    Greece     None

# %% [markdown]
# Now, there are values of 'Country' which contains stuff like 'Over', 'Off', 'Near', etc. Which I will now remove.

# %%
prefix_regex = r'^(Near|Off the|off the|Over the|Off|off|Over|the)\s'

df['Country'] = df['Country'].str.replace(prefix_regex, '', regex=True)

# %% [markdown]
# Replacing the rest of the values

# %%
df['Country'] = df['Country'].replace({
    'Alaska coast': 'United States of America',
    'Bimini': 'Bahamas',
    'Cape Verde Islands': 'Cape Verde',
    'Chili': 'Chile',
    'Eastern Libya': 'Libya',
    'English Channel': 'United Kingdom',
    'Eugene Island': 'United States of America',
    'Gulf of Finland': 'Finland',
    'Gulf of Karkinitsky': 'Ukraine',
    'Gulf of Sirte': 'Libya',
    'Gulf of Tonkin': 'Vietnam',
    'Irish coast': 'Ireland',
    'Malta-Luqa': 'Malta',
    'Mediterranean': 'Mediterranean Sea',
    'North Atlantic': 'Atlantic Ocean',
    'North Pacific Ocean': 'Pacific Ocean',
    'Northern Germany': 'Germany',
    'Okinawa': 'Japan',
    'Ontario': 'Canada',
    'Oregon coast': 'United States of America',
    'Pacific Ocean between Hong Kong and Macao': 'Pacific Ocean',
    'Pacific Ocean between Manila and Guam': 'Pacific Ocean',
    'Panama coast': 'Panama',
    'Phillipines': 'Philippines',
    'Philipines': 'Philippines',
    'Philippine Sea': 'Philippines',
    'Philippine island of Elalat': 'Philipines',
    'Rhodesia (Zimbabwe)': 'Zimbabwe',
    'Santiago de Cuba': 'Cuba',
    'Sao Gabriel de Cachoeria': 'Brazil',
    'Sarawak': 'Malaysia',
    'Scotland': 'United Kingdom',
    'Sea of Japan': 'Japan',
    'Sierre Leone': 'Sierra Leone',
    'South Atlantic Ocean': 'Atlantic Ocean',
    'South Australia': 'Australia',
    'South Indian Ocean': 'Indian Ocean',
    'South Kazakistan': 'Kazakistan',
    'South Vietnam': 'Vietnam',
    'South Yemen': 'Yemen',
    'South of Gibraltar': 'Gibraltar',
    'Southeastern Bolivia': 'Bolivia',
    'South-West Africa (Namibia)': 'Namibia',
    'Soviet Union': 'Russia',
    'Spain Canary Islands': 'Spain',
    'Tabones Island Philippines': 'Philippines',
    'Tanganyika': 'Tanzania',
    'Tasmania': 'Australia',
    'USSR': 'Russia',
    'U.S. Virgin Islands': 'US Virgin Islands',
    'UAE': 'United Arab Emirates',
    'UAR': 'Egypt',
    'United States': 'United States of America',
    'Uzbekstan': 'Uzbekistan',
    'Virgin Islands': 'US Virgin Islands',
    'Washington': 'United States of America',
    'West Germany': 'Germany',
    'West Pakistan': 'Pakistan',
    'Western Samoa': 'Samoa',
    'Yukon Territory': 'Canada',
    'coast of France': 'France',
    'western Denmark': 'Denmark',
    '800 miles east of Newfoundland': 'Canada',
    'of Gibraltar': 'Gibraltar',
    'South Koren': 'South Korea',
    'Pest Hungary': 'Hungary',
    'British Columbia Canada': 'Canada',
    'Columbia': 'Colombia',
    'Washington D.C.': 'United States of America',
    'French Somaliland': 'Somalia',
    'South Korean': 'South Korea',
    'Papua New Guinea': 'New Guinea',
    'Philipines': 'Philippines',
    'Territory of New Guinea': 'New Guinea',
    'Upper Volta': 'Burkina Faso',
    'of Gibraltar': 'Gibraltar',
    'Zaire': 'Democratic Republic of the Congo',
    'Kazakistan': 'Kazakhstan',
    'Central Mozambique': 'Mozambique',
    '?': 'Unknown',
    'Algiers': 'Algeria'
})

# %%
area_values = df['Country'].unique()
area_values.sort()
for value in area_values:
    print(value)
# Out:
# Aegean Sea
# Afghanistan
# Africa
# Albania
# Algeria
# American Samoa
# Andaman Sea
# Andes
# Angola
# Antarctica
# Antigua
# Argentina
# Armenia
# Atlantic Ocean
# Australia
# Austria
# Azerbaijan
# Azores
# Bahamas
# Bahrain
# Baltic Sea
# Bangladesh
# Barbados
# Belarus
# Belgian Congo
# Belgium
# Benin
# Bermuda
# Bhutan
# Black Sea
# Bolivia
# Borneo
# Bosnia and Herzegovina
# Botswana
# Brazil
# British Cameroons
# British Virgin Islands
# Brunei
# Bulgaria
# Burkina Faso
# Cambodia
# Cameroon
# Canada
# Canary Islands
# Cape Verde
# Carribean Sea
# Central African Republic
# Chad
# Chile
# China
# Colombia
# Comoros Islands
# Congo
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Democratic Republic of Congo
# Democratic Republic of the Congo
# Denmark
# Desertores Island Región de Los Lagos
# Djibouti
# Dominican Republic
# East Timor
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Fiji
# Finland
# France
# French Cameroons
# French Equatorial Africa
# French Indo-China
# French Polynesia
# French West Africa
# French West Indies
# Gabon
# Gambia
# Germany
# Ghana
# Gibraltar
# Greece
# Greenland
# Guadeloupe
# Guam
# Guatemala
# Guinea
# Guyana
# Haiti
# Honduras
# Hong Kong
# Hungary
# Iceland
# India
# Indian Ocean
# Indonesia
# Iran
# Iraq
# Ireland
# Isle of Man
# Israel
# Italy
# Ivory Coast
# Jamaica
# Japan
# Java Sea
# Jersey
# Jordan
# Katanga
# Kazakhstan
# Kazakistan
# Kenya
# Khmer Republic
# Kosovo
# Kuwait
# Kyrgyzstan
# Labrador
# Laos
# Latvia
# Lebanon
# Leeward Islands
# Lesotho
# Liberia
# Libya
# Luxembourg
# Macedonia
# Madagascar
# Malawi
# Malaya
# Malaysia
# Mali
# Malta
# Mariana Islands
# Marshall Islands
# Martinique
# Mauritania
# Mediterranean Sea
# Mexico
# Micronesia
# Moldova
# Mongolia
# Montserrat
# Morocco
# Mozambique
# Myanmar
# Nag
# Nambia
# Namibia
# Nepal
# Netherlands
# Netherlands Antilles
# Netherlands Indies
# New Caledonia
# New Guinea
# New Zealand
# Nicaragua
# Niger
# Nigeria
# North Carolina
# North Korea
# North Sea
# Norway
# Oman
# Pacific Ocean
# Pakistan
# Panama
# Paraguay
# Persian Gulf
# Peru
# Philipines
# Philippines
# Poland
# Portugal
# Puerto Rico
# Qatar
# Reunion
# Romania
# Russia
# Rwanda
# Saint Lucia Island
# Samoa
# Saudi Arabia
# Senegal
# Sierra Leone
# Singapore
# Slovakia
# Slovenia
# Solomon Islands
# Somalia
# South Africa
# South Korea
# South Sudan
# Spain
# Sri Lanka
# Sudan
# Suriname
# Sweden
# Switzerland
# Syria
# São Tomé Island
# Tahiti
# Taiwan
# Tajikistan
# Tanzania
# Thailand
# Timor
# Trinidad
# Tunisia
# Turkey
# Turkmenistan
# Turks and Caicos Islands
# U.S. Samoa
# US Virgin Islands
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# United States of America
# Unknown
# Uruguay
# Uzbekistan
# Vanuatu
# Venezuela
# Vietnam
# Wake Island
# Wales
# West Africa
# West Indies
# Western Africa
# Yemen
# Yugoslavia
# Zambia
# Zimbabwe

# %% [markdown]
# ### Finding number of people on board, fatalities and survivors.

# %%
import re

# %%
test_str = df.head(1)['Aboard'].values.tolist()[0]
test_str
# Out:
# '72 (passengers:68 crew:4)'

# %%
passenger_parser = re.compile(
    '''
    (\d+)               # Total
    \s                  # Blank space
    \(                  # Opening bracket
    passengers:         # Fixed string
    (.+)                # Number of passengers
    \s
    crew:
    (.+)                # Number of crew
    \)
    ''', re.VERBOSE)

# %% [markdown]
# Processing the number of people abroad

# %%
abroad_parts = df['Aboard'].str.extract(passenger_parser)
df['Total_abroad'], df['Passengers_abroad'], df['Crew_abroad'] = abroad_parts[0], abroad_parts[1], abroad_parts[2]

# %% [markdown]
# Processing the number of casualties

# %%
fatalities_parts = df['Fatalities'].str.extract(passenger_parser)
df['Total_fatalities'], df['Passengers_fatalities'], df['Crew_fatalities'] = fatalities_parts[0], fatalities_parts[1], fatalities_parts[2]

# %% [markdown]
# Now that the column has been split into three, the original columns can be dropped.

# %%
df = df.drop(['Fatalities', 'Aboard'], axis=1)
df.head()
# Out:
#         Date  Time       Operator Flight_No                  Route  \
# 0 2023-01-15  1050  Yeti Airlines     YT691    Kathmandu - Pokhara
# 1 2022-11-21  1015   AeroPaca SAS         ?     Medellín - Pizarro
# 2 2022-11-18  1511          LATAM    LA2213         Lima - Juliaca
# 3 2022-11-06  0853  Precision Air     PW494  Dar es-Salaam -Bukoba
# 4 2022-07-16  2247       Meridian   MEM3032             Nis- Amman
#
#                             AC_Type Registration       cn_ln Ground  Decade  \
# 0               ATR 72-500-72-212-A        9NANC         754      0    2020
# 1  Piper PA-31-350 Navajo Chieftain      HK-5121  31-7652004      0    2020
# 2                   Airbus 320-271N       CC-BHB        7864      2    2020
# 3                        ATR 42-500       5H-PWF         819      0    2020
# 4                     Antonov An-12       UR-CIC    01347701      0    2020
#
#               City   Country US_State Total_abroad Passengers_abroad  \
# 0          Pokhara     Nepal     None           72                68
# 1         Medellín  Colombia     None            8                 6
# 2             Lima      Peru     None          108               102
# 3           Bukoba  Tanzania     None           43                39
# 4  Eleftheroupolis    Greece     None            8                 0
#
#   Crew_abroad Total_fatalities Passengers_fatalities Crew_fatalities
# 0           4               72                    68               4
# 1           2                8                     6               2
# 2           6                0                     0               0
# 3          39               19                    17               2
# 4           8                8                     0               8

# %% [markdown]
# ### Splitting route into source and destination.

# %%
route_parts = df['Route'].str.split('-')

destination = route_parts.apply(lambda x: x[-1])
source = route_parts.apply(lambda x: '-'.join(x[:-1]))

df['Source'] = source
df['Destination'] = destination

# Now strip away the trailing whitespaces
df['Source'] = df['Source'].str.strip()
df['Destination'] = df['Destination'].str.strip()

# %% [markdown]
# Now drop the route.

# %%
df = df.drop('Route', axis=1)

# %% [markdown]
# Now convert some other columns

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%H%M', errors='coerce').dt.time

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4596 entries, 0 to 4595
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   4596 non-null   datetime64[ns]
#  1   Time                   3223 non-null   object
#  2   Operator               4596 non-null   object
#  3   Flight_No              4596 non-null   object
#  4   AC_Type                4596 non-null   object
#  5   Registration           4596 non-null   object
#  6   cn_ln                  4596 non-null   object
#  7   Ground                 4596 non-null   object
#  8   Decade                 4596 non-null   int64
#  9   City                   4596 non-null   object
#  10  Country                4596 non-null   object
#  11  US_State               964 non-null    object
#  12  Total_abroad           4582 non-null   object
#  13  Passengers_abroad      4582 non-null   object
#  14  Crew_abroad            4582 non-null   object
#  15  Total_fatalities       4590 non-null   object
#  16  Passengers_fatalities  4590 non-null   object
#  17  Crew_fatalities        4590 non-null   object
#  18  Source                 4596 non-null   object
#  19  Destination            4596 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(18)
# memory usage: 718.2+ KB

# %%
num_cols = ['Total_abroad', 'Ground', 'Passengers_abroad', 'Crew_abroad', 'Total_fatalities', 'Passengers_fatalities', 'Crew_fatalities']

for column in num_cols:
    df[column] = df[column].replace({'?': np.nan})
    df[column] = df[column].astype('Int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4596 entries, 0 to 4595
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   4596 non-null   datetime64[ns]
#  1   Time                   3223 non-null   object
#  2   Operator               4596 non-null   object
#  3   Flight_No              4596 non-null   object
#  4   AC_Type                4596 non-null   object
#  5   Registration           4596 non-null   object
#  6   cn_ln                  4596 non-null   object
#  7   Ground                 4556 non-null   Int16
#  8   Decade                 4596 non-null   int64
#  9   City                   4596 non-null   object
#  10  Country                4596 non-null   object
#  11  US_State               964 non-null    object
#  12  Total_abroad           4582 non-null   Int16
#  13  Passengers_abroad      4396 non-null   Int16
#  14  Crew_abroad            4398 non-null   Int16
#  15  Total_fatalities       4590 non-null   Int16
#  16  Passengers_fatalities  4384 non-null   Int16
#  17  Crew_fatalities        4384 non-null   Int16
#  18  Source                 4596 non-null   object
#  19  Destination            4596 non-null   object
# dtypes: Int16(7), datetime64[ns](1), int64(1), object(11)
# memory usage: 561.2+ KB

# %% [markdown]
# Introduce three new survivors colmns.

# %%
df['Total_survivors'] = df['Total_abroad'] - df['Total_fatalities']
df['Passengers_survivors'] = df['Passengers_abroad'] - df['Passengers_fatalities']
df['Crew_survivors'] = df['Crew_abroad'] - df['Crew_fatalities']

# %%
place_names = sorted(df['Destination'].unique().tolist())
with open('Place_names.txt', 'w') as file:
    for name in place_names:
        file.write(f'{name}\n')

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
day_order = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']

# %%
pd.set_option('display.max_columns', 50)

# %% [markdown]
# ## 1.1. Make a column for survival percentage

# %%
df['Survival_rate'] = (df['Total_survivors'] / df['Total_abroad']) * 100
df.head()
# Out:
#         Date      Time       Operator Flight_No  \
# 0 2023-01-15  10:50:00  Yeti Airlines     YT691
# 1 2022-11-21  10:15:00   AeroPaca SAS         ?
# 2 2022-11-18  15:11:00          LATAM    LA2213
# 3 2022-11-06  08:53:00  Precision Air     PW494
# 4 2022-07-16  22:47:00       Meridian   MEM3032
#
#                             AC_Type Registration       cn_ln  Ground  Decade  \
# 0               ATR 72-500-72-212-A        9NANC         754       0    2020
# 1  Piper PA-31-350 Navajo Chieftain      HK-5121  31-7652004       0    2020
# 2                   Airbus 320-271N       CC-BHB        7864       2    2020
# 3                        ATR 42-500       5H-PWF         819       0    2020
# 4                     Antonov An-12       UR-CIC    01347701       0    2020
#
#               City   Country US_State  Total_abroad  Passengers_abroad  \
# 0          Pokhara     Nepal     None            72                 68
# 1         Medellín  Colombia     None             8                  6
# 2             Lima      Peru     None           108                102
# 3           Bukoba  Tanzania     None            43                 39
# 4  Eleftheroupolis    Greece     None             8                  0
#
#    Crew_abroad  Total_fatalities  Passengers_fatalities  Crew_fatalities  \
# 0            4                72                     68                4
# 1            2                 8                      6                2
# 2            6                 0                      0                0
# 3           39                19                     17                2
# 4            8                 8                      0                8
#
#           Source Destination  Total_survivors  Passengers_survivors  \
# 0      Kathmandu     Pokhara                0                     0
# 1       Medellín     Pizarro                0                     0
# 2           Lima     Juliaca              108                   102
# 3  Dar es-Salaam      Bukoba               24                    22
# 4            Nis       Amman                0                     0
#
#    Crew_survivors  Survival_rate
# 0               0            0.0
# 1               0            0.0
# 2               6          100.0
# 3              37      55.813953
# 4               0            0.0

# %% [markdown]
# ## 1.2 Making a type column for making passenger or military aircraft

# %%
def determine_type(value):
    if 'military' in value.lower():
        return 'Military'
    else:
        return 'Passenger'
    
df['Type'] = df['Operator'].apply(lambda x: determine_type(x))
df.head()
# Out:
#         Date      Time       Operator Flight_No  \
# 0 2023-01-15  10:50:00  Yeti Airlines     YT691
# 1 2022-11-21  10:15:00   AeroPaca SAS         ?
# 2 2022-11-18  15:11:00          LATAM    LA2213
# 3 2022-11-06  08:53:00  Precision Air     PW494
# 4 2022-07-16  22:47:00       Meridian   MEM3032
#
#                             AC_Type Registration       cn_ln  Ground  Decade  \
# 0               ATR 72-500-72-212-A        9NANC         754       0    2020
# 1  Piper PA-31-350 Navajo Chieftain      HK-5121  31-7652004       0    2020
# 2                   Airbus 320-271N       CC-BHB        7864       2    2020
# 3                        ATR 42-500       5H-PWF         819       0    2020
# 4                     Antonov An-12       UR-CIC    01347701       0    2020
#
#               City   Country US_State  Total_abroad  Passengers_abroad  \
# 0          Pokhara     Nepal     None            72                 68
# 1         Medellín  Colombia     None             8                  6
# 2             Lima      Peru     None           108                102
# 3           Bukoba  Tanzania     None            43                 39
# 4  Eleftheroupolis    Greece     None             8                  0
#
#    Crew_abroad  Total_fatalities  Passengers_fatalities  Crew_fatalities  \
# 0            4                72                     68                4
# 1            2                 8                      6                2
# 2            6                 0                      0                0
# 3           39                19                     17                2
# 4            8                 8                      0                8
#
#           Source Destination  Total_survivors  Passengers_survivors  \
# 0      Kathmandu     Pokhara                0                     0
# 1       Medellín     Pizarro                0                     0
# 2           Lima     Juliaca              108                   102
# 3  Dar es-Salaam      Bukoba               24                    22
# 4            Nis       Amman                0                     0
#
#    Crew_survivors  Survival_rate       Type
# 0               0            0.0  Passenger
# 1               0            0.0  Passenger
# 2               6          100.0  Passenger
# 3              37      55.813953  Passenger
# 4               0            0.0  Passenger

# %% [markdown]
# ## 1.3 Making columns for day of the week and month name

# %%
df['Month'] = df['Date'].dt.month
df['Month'] = df['Month'].apply(lambda x: pd.datetime.strptime(str(x), '%m').strftime('%B'))
df['Day_of_week'] = df['Date'].dt.strftime('%A')
df.iloc[:5, -2:]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11680\29041736.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df['Month'] = df['Month'].apply(lambda x: pd.datetime.strptime(str(x), '%m').strftime('%B'))
#       Month Day_of_week
# 0   January      Sunday
# 1  November      Monday
# 2  November      Friday
# 3  November      Sunday
# 4      July    Saturday

# %%
df['Month'] = pd.Categorical(df['Month'], categories=month_order, ordered=True)
df['Day_of_week'] = pd.Categorical(df['Day_of_week'], categories=day_order, ordered=True)
df['US_State'] = pd.Categorical(df['US_State'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4596 entries, 0 to 4595
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   4596 non-null   datetime64[ns]
#  1   Time                   3223 non-null   object
#  2   Operator               4596 non-null   object
#  3   Flight_No              4596 non-null   object
#  4   AC_Type                4596 non-null   object
#  5   Registration           4596 non-null   object
#  6   cn_ln                  4596 non-null   object
#  7   Ground                 4556 non-null   Int16
#  8   Decade                 4596 non-null   int64
#  9   City                   4596 non-null   object
#  10  Country                4596 non-null   object
#  11  US_State               964 non-null    category
#  12  Total_abroad           4582 non-null   Int16
#  13  Passengers_abroad      4396 non-null   Int16
#  14  Crew_abroad            4398 non-null   Int16
#  15  Total_fatalities       4590 non-null   Int16
#  16  Passengers_fatalities  4384 non-null   Int16
#  17  Crew_fatalities        4384 non-null   Int16
#  18  Source                 4596 non-null   object
#  19  Destination            4596 non-null   object
#  20  Total_survivors        4582 non-null   Int16
#  21  Passengers_survivors   4379 non-null   Int16
#  22  Crew_survivors         4381 non-null   Int16
#  23  Survival_rate          4582 non-null   Float64
#  24  Type                   4596 non-null   object
#  25  Month                  4596 non-null   category
#  26  Day_of_week            4596 non-null   category
# dtypes: Float64(1), Int16(10), category(3), datetime64[ns](1), int64(1), object(11)
# memory usage: 657.6+ KB

# %% [markdown]
# ## 1.4 Continent column

# %%
continent_dict = {'NA': 'North America', 'SA': 'South America', 'EU': 'Europe', 'AF': 'Africa', 'AS': 'Asia', 'OC': 'Oceania'}

# %%
def get_continent_code(x):
    try:
        country_code = pycountry_convert.country_name_to_country_alpha2(x)
        continent_code = pycountry_convert.country_alpha2_to_continent_code(country_code)
        return continent_code
    except:
        return None

df['Continent Code'] = df['Country'].apply(lambda x: get_continent_code(x))
df['Continent'] = df['Continent Code'].map(continent_dict)
df = df.drop('Continent Code', axis=1)

# %% [markdown]
# # SAVE THE DATAFRAME

# %%
df.to_csv('Processed_dataset/Crash_data_new.csv', index=False)
df.to_parquet('Processed_dataset/Crash_data_new.parquet')

# %%
df['US_State'].unique()
# Out:
# [NaN, 'California', 'Alaska', 'Ohio', 'Texas', ..., 'Oregon', 'Rhode Island', 'Nebraska', 'Oklahoma', 'Delaware']
# Length: 50
# Categories (49, object): ['Alabama', 'Alaska', 'Arizona', 'Arkansas', ..., 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']

# %%
df.head()
# Out:
#         Date      Time       Operator Flight_No  \
# 0 2023-01-15  10:50:00  Yeti Airlines     YT691
# 1 2022-11-21  10:15:00   AeroPaca SAS         ?
# 2 2022-11-18  15:11:00          LATAM    LA2213
# 3 2022-11-06  08:53:00  Precision Air     PW494
# 4 2022-07-16  22:47:00       Meridian   MEM3032
#
#                             AC_Type Registration       cn_ln  Ground  Decade  \
# 0               ATR 72-500-72-212-A        9NANC         754       0    2020
# 1  Piper PA-31-350 Navajo Chieftain      HK-5121  31-7652004       0    2020
# 2                   Airbus 320-271N       CC-BHB        7864       2    2020
# 3                        ATR 42-500       5H-PWF         819       0    2020
# 4                     Antonov An-12       UR-CIC    01347701       0    2020
#
#               City   Country US_State  Total_abroad  Passengers_abroad  \
# 0          Pokhara     Nepal      NaN            72                 68
# 1         Medellín  Colombia      NaN             8                  6
# 2             Lima      Peru      NaN           108                102
# 3           Bukoba  Tanzania      NaN            43                 39
# 4  Eleftheroupolis    Greece      NaN             8                  0
#
#    Crew_abroad  Total_fatalities  Passengers_fatalities  Crew_fatalities  \
# 0            4                72                     68                4
# 1            2                 8                      6                2
# 2            6                 0                      0                0
# 3           39                19                     17                2
# 4            8                 8                      0                8
#
#           Source Destination  Total_survivors  Passengers_survivors  \
# 0      Kathmandu     Pokhara                0                     0
# 1       Medellín     Pizarro                0                     0
# 2           Lima     Juliaca              108                   102
# 3  Dar es-Salaam      Bukoba               24                    22
# 4            Nis       Amman                0                     0
#
#    Crew_survivors  Survival_rate       Type     Month Day_of_week  \
# 0               0            0.0  Passenger   January      Sunday
# 1               0            0.0  Passenger  November      Monday
# 2               6          100.0  Passenger  November      Friday
# 3              37      55.813953  Passenger  November      Sunday
# 4               0            0.0  Passenger      July    Saturday
#
#        Continent
# 0           Asia
# 1  South America
# 2  South America
# 3         Africa
# 4         Europe

# %%
area_values = df['Country'].unique()
area_values.sort()
for value in area_values:
    print(value)
# Out:
# Aegean Sea
# Afghanistan
# Africa
# Albania
# Algeria
# American Samoa
# Andaman Sea
# Andes
# Angola
# Antarctica
# Antigua
# Argentina
# Armenia
# Atlantic Ocean
# Australia
# Austria
# Azerbaijan
# Azores
# Bahamas
# Bahrain
# Baltic Sea
# Bangladesh
# Barbados
# Belarus
# Belgian Congo
# Belgium
# Benin
# Bermuda
# Bhutan
# Black Sea
# Bolivia
# Borneo
# Bosnia and Herzegovina
# Botswana
# Brazil
# British Cameroons
# British Virgin Islands
# Brunei
# Bulgaria
# Burkina Faso
# Cambodia
# Cameroon
# Canada
# Canary Islands
# Cape Verde
# Carribean Sea
# Central African Republic
# Chad
# Chile
# China
# Colombia
# Comoros Islands
# Congo
# Cook Islands
# Costa Rica
# Croatia
# Cuba
# Cyprus
# Czech Republic
# Democratic Republic of Congo
# Democratic Republic of the Congo
# Denmark
# Desertores Island Región de Los Lagos
# Djibouti
# Dominican Republic
# East Timor
# Ecuador
# Egypt
# El Salvador
# Equatorial Guinea
# Eritrea
# Estonia
# Ethiopia
# Fiji
# Finland
# France
# French Cameroons
# French Equatorial Africa
# French Indo-China
# French Polynesia
# French West Africa
# French West Indies
# Gabon
# Gambia
# Germany
# Ghana
# Gibraltar
# Greece
# Greenland
# Guadeloupe
# Guam
# Guatemala
# Guinea
# Guyana
# Haiti
# Honduras
# Hong Kong
# Hungary
# Iceland
# India
# Indian Ocean
# Indonesia
# Iran
# Iraq
# Ireland
# Isle of Man
# Israel
# Italy
# Ivory Coast
# Jamaica
# Japan
# Java Sea
# Jersey
# Jordan
# Katanga
# Kazakhstan
# Kazakistan
# Kenya
# Khmer Republic
# Kosovo
# Kuwait
# Kyrgyzstan
# Labrador
# Laos
# Latvia
# Lebanon
# Leeward Islands
# Lesotho
# Liberia
# Libya
# Luxembourg
# Macedonia
# Madagascar
# Malawi
# Malaya
# Malaysia
# Mali
# Malta
# Mariana Islands
# Marshall Islands
# Martinique
# Mauritania
# Mediterranean Sea
# Mexico
# Micronesia
# Moldova
# Mongolia
# Montserrat
# Morocco
# Mozambique
# Myanmar
# Nag
# Nambia
# Namibia
# Nepal
# Netherlands
# Netherlands Antilles
# Netherlands Indies
# New Caledonia
# New Guinea
# New Zealand
# Nicaragua
# Niger
# Nigeria
# North Carolina
# North Korea
# North Sea
# Norway
# Oman
# Pacific Ocean
# Pakistan
# Panama
# Paraguay
# Persian Gulf
# Peru
# Philipines
# Philippines
# Poland
# Portugal
# Puerto Rico
# Qatar
# Reunion
# Romania
# Russia
# Rwanda
# Saint Lucia Island
# Samoa
# Saudi Arabia
# Senegal
# Sierra Leone
# Singapore
# Slovakia
# Slovenia
# Solomon Islands
# Somalia
# South Africa
# South Korea
# South Sudan
# Spain
# Sri Lanka
# Sudan
# Suriname
# Sweden
# Switzerland
# Syria
# São Tomé Island
# Tahiti
# Taiwan
# Tajikistan
# Tanzania
# Thailand
# Timor
# Trinidad
# Tunisia
# Turkey
# Turkmenistan
# Turks and Caicos Islands
# U.S. Samoa
# US Virgin Islands
# Uganda
# Ukraine
# United Arab Emirates
# United Kingdom
# United States of America
# Unknown
# Uruguay
# Uzbekistan
# Vanuatu
# Venezuela
# Vietnam
# Wake Island
# Wales
# West Africa
# West Indies
# Western Africa
# Yemen
# Yugoslavia
# Zambia
# Zimbabwe

# %%
sorted(df['Country'].unique())
# Out:
# ['Aegean Sea',
#  'Afghanistan',
#  'Africa',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andaman Sea',
#  'Andes',
#  'Angola',
#  'Antarctica',
#  'Antigua',
#  'Argentina',
#  'Armenia',
#  'Atlantic Ocean',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Azores',
#  'Bahamas',
#  'Bahrain',
#  'Baltic Sea',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgian Congo',
#  'Belgium',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Black Sea',
#  'Bolivia',
#  'Borneo',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Cameroons',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Canary Islands',
#  'Cape Verde',
#  'Carribean Sea',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Colombia',
#  'Comoros Islands',
#  'Congo',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Democratic Republic of Congo',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Desertores Island Región de Los Lagos',
#  'Djibouti',
#  'Dominican Republic',
#  'East Timor',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Ethiopia',
#  'Fiji',
#  'Finland',
#  'France',
#  'French Cameroons',
#  'French Equatorial Africa',
#  'French Indo-China',
#  'French Polynesia',
#  'French West Africa',
#  'French West Indies',
#  'Gabon',
#  'Gambia',
#  'Germany',
#  'Ghana',
#  'Gibraltar',
#  'Greece',
#  'Greenland',
#  'Guadeloupe',
#  'Guam',
#  'Guatemala',
#  'Guinea',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indian Ocean',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Isle of Man',
#  'Israel',
#  'Italy',
#  'Ivory Coast',
#  'Jamaica',
#  'Japan',
#  'Java Sea',
#  'Jersey',
#  'Jordan',
#  'Katanga',
#  'Kazakhstan',
#  'Kazakistan',
#  'Kenya',
#  'Khmer Republic',
#  'Kosovo',
#  'Kuwait',
#  'Kyrgyzstan',
#  'Labrador',
#  'Laos',
#  'Latvia',
#  'Lebanon',
#  'Leeward Islands',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Luxembourg',
#  'Macedonia',
#  'Madagascar',
#  'Malawi',
#  'Malaya',
#  'Malaysia',
#  'Mali',
#  'Malta',
#  'Mariana Islands',
#  'Marshall Islands',
#  'Martinique',
#  'Mauritania',
#  'Mediterranean Sea',
#  'Mexico',
#  'Micronesia',
#  'Moldova',
#  'Mongolia',
#  'Montserrat',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Nag',
#  'Nambia',
#  'Namibia',
#  'Nepal',
#  'Netherlands',
#  'Netherlands Antilles',
#  'Netherlands Indies',
#  'New Caledonia',
#  'New Guinea',
#  'New Zealand',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Carolina',
#  'North Korea',
#  'North Sea',
#  'Norway',
#  'Oman',
#  'Pacific Ocean',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Persian Gulf',
#  'Peru',
#  'Philipines',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Puerto Rico',
#  'Qatar',
#  'Reunion',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint Lucia Island',
#  'Samoa',
#  'Saudi Arabia',
#  'Senegal',
#  'Sierra Leone',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Suriname',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'São Tomé Island',
#  'Tahiti',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor',
#  'Trinidad',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Turks and Caicos Islands',
#  'U.S. Samoa',
#  'US Virgin Islands',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States of America',
#  'Unknown',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela',
#  'Vietnam',
#  'Wake Island',
#  'Wales',
#  'West Africa',
#  'West Indies',
#  'Western Africa',
#  'Yemen',
#  'Yugoslavia',
#  'Zambia',
#  'Zimbabwe']
